# %%
## Import Basic Liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Pull the Training Data
data = pd.read_excel('Data_Train.xlsx')

# %%
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# 3        NaN   6.00
# 4        NaN  17.74

# %%
### 13 Features and 6019 Data Set
data.shape
# Out:
# (6019, 13)

# %%
## Checking for the null values
data.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
data['Engine'].isnull().T.any()
# Out:
# True

# %%
data1 = data.copy()

# %%
data.shape
# Out:
# (6019, 13)

# %%
data1.shape
# Out:
# (6019, 13)

# %%
data['Engine'].dropna(how=any,inplace=True)

# %%
data.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
### Deleting the NaN Values from Features Engine, Power.
data.dropna(subset=['Engine'],inplace=True)
## Dropping the nan for Mileage and Seats Features
data.dropna(subset=['Mileage'],inplace=True)
data.dropna(subset=['Seats'],inplace=True)

# %%
data.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            5152
# Price                   0
# dtype: int64

# %%
## Dropping the column
##data['New_Price'].drop(inplace=True)
data.drop(['New_Price'],axis=1,inplace=True)

# %%
### Now the Data is Clean 
data.isna().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
data.head(2)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# #### FEATURES:
#
# Name: The brand and model of the car.
#
# Location: The location in which the car is being sold or is available for purchase.
#
# Year: The year or edition of the model.
#
# Kilometers_Driven: The total kilometres driven in the car by the previous owner(s) in KM.
#
# Fuel_Type: The type of fuel used by the car.
#
# Transmission: The type of transmission used by the car.
#
# Owner_Type: Whether the ownership is Firsthand, Second hand or other.
#
# Mileage: The standard mileage offered by the car company in kmpl or km/kg
#
# Engine: The displacement volume of the engine in cc.
#
# Power: The maximum power of the engine in bhp.
#
# Seats: The number of seats in the car.
#
# New_Price: The price of a new car of the same model.
#
# Price: The price of the used car in INR Lakhs.

# %%
data['Name'].nunique()
# Out:
# 1855

# %%
data['Location'].nunique()
# Out:
# 11

# %%
data['Name'].value_counts()
# Out:
# Mahindra XUV500 W8 2WD                                49
# Maruti Swift VDI                                      45
# Honda City 1.5 S MT                                   34
# Maruti Swift Dzire VDI                                34
# Maruti Swift VDI BSIV                                 31
# Hyundai i10 Sportz                                    30
# Maruti Ritz VDi                                       30
# Toyota Fortuner 3.0 Diesel                            29
# Honda Amaze S i-Dtech                                 27
# Hyundai Grand i10 Sportz                              27
# Honda Brio S MT                                       25
# Maruti Ertiga VDI                                     25
# Honda City 1.5 V MT                                   24
# Maruti Wagon R VXI                                    23
# Hyundai Verna 1.6 SX                                  23
# Maruti Wagon R LXI                                    22
# Maruti Alto LXi                                       21
# Maruti Alto 800 LXI                                   20
# Hyundai EON Era Plus                                  20
# BMW 3 Series 320d                                     20
# Maruti Ertiga ZDI                                     20
# Skoda Superb Elegance 1.8 TSI AT                      20
# Hyundai i10 Magna 1.2                                 19
# Toyota Fortuner 4x2 AT                                19
# Maruti Celerio VXI AT                                 19
# Renault KWID RXT                                      18
# Volkswagen Vento Diesel Highline                      18
# Hyundai i20 1.2 Magna                                 18
# Volkswagen Polo 1.5 TDI Highline                      18
# Maruti Wagon R LXI CNG                                18
#                                                       ..
# Mahindra Bolero SLE BSIII                              1
# Honda Accord VTi-L MT                                  1
# Mahindra Scorpio VLX AT AIRBAG BSIV                    1
# Skoda Rapid 1.5 TDI AT Elegance Plus Black Package     1
# Maruti Alto 800 CNG LXI                                1
# Tata Manza Aura Quadrajet                              1
# Hyundai Elite i20 Diesel Asta Option                   1
# Chevrolet Enjoy 1.4 LS 8                               1
# Ford Ecosport 1.5 Ti VCT MT Trend                      1
# Toyota Etios 1.4 VXD                                   1
# Tata Indica V2 DLS TC                                  1
# Hyundai Elantra 1.6 SX                                 1
# Mercedes-Benz New C-Class C 200 AVANTGARDE             1
# Renault Fluence 2.0                                    1
# Mercedes-Benz GLA Class 200 Sport                      1
# BMW 3 Series GT 320d Luxury Line                       1
# Mahindra Xylo D2 BS III                                1
# Tata Safari Storme Explorer Edition                    1
# Tata Bolt Quadrajet XM                                 1
# Maruti Dzire AMT VXI                                   1
# Ambassador Classic Nova Diesel                         1
# Mercedes-Benz E-Class E 200 CGI                        1
# Ford Figo Petrol LXI                                   1
# Hyundai Verna 1.6 i ABS                                1
# Skoda Octavia 1.9 TDI                                  1
# Toyota Innova 2.0 G1                                   1
# Volvo V40 D3                                           1
# Honda Accord 2001-2003 2.0 AT                          1
# Mini Cooper Convertible 1.6                            1
# Maruti Wagon R LX BS IV                                1
# Name: Name, Length: 1855, dtype: int64

# %%
print('Location of CARS \n',data['Location'].value_counts())
print('-----------------------------\n')
print('CARs Manufacture Year \n ',data['Year'].value_counts())
print('-----------------------------\n')
print('Fuel Engines \n ',data['Fuel_Type'].value_counts())
print('-----------------------------')
print('\nTransmission Manual And Auto\n',data['Transmission'].value_counts())
print('-----------------------------')
print('Onwership of the CARS \n', data['Owner_Type'].value_counts())
# Out:
# Location of CARS
#  Mumbai        784
# Hyderabad     741
# Kochi         648
# Coimbatore    634
# Pune          613
# Delhi         549
# Kolkata       530
# Chennai       490
# Jaipur        410
# Bangalore     353
# Ahmedabad     223
# Name: Location, dtype: int64
# -----------------------------
#
# CARs Manufacture Year
#   2014    795
# 2015    741
# 2016    740
# 2013    648
# 2017    586
# 2012    572
# 2011    461
# 2010    339
# 2018    298
# 2009    196
# 2008    169
# 2007    123
# 2019    102
# 2006     75
# 2005     55
# 2004     29
# 2003     15
# 2002     14
# 2001      7
# 1998      4
# 2000      4
# 1999      2
# Name: Year, dtype: int64
# -----------------------------
#
# Fuel Engines
#   Diesel    3195
# Petrol    2714
# CNG         56
# LPG         10
# Name: Fuel_Type, dtype: int64
# -----------------------------
#
# Transmission Manual And Auto
#  Manual       4266
# Automatic    1709
# Name: Transmission, dtype: int64
# -----------------------------
# Onwership of the CARS
#  First             4903
# Second             953
# Third              111
# Fourth & Above       8
# Name: Owner_Type, dtype: int64

# %%
##('CAR Mileage  \n ',data['Mileage'].value_counts())
##print('-----------------------------\n')
##print('CAR Engine \n ',data['Engine'].value_counts())
##print('-----------------------------\n')
##print('CAR Horse Power \n ',data['Power'].value_counts())
##print('-----------------------------')
print('CARs Seats \n',data['Seats'].value_counts())
print('-----------------------------')
# Out:
# CARs Seats
#  5.0     5012
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64
# -----------------------------

# %%
data.head(2)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50

# %%
## In the Data set ,most of the vehicles manufacturing is between 2005 and 2020
# figure size in inches
from matplotlib import rcParams
rcParams['figure.figsize'] = 11.7,8.27
import seaborn as sb
sb.scatterplot(data['Name'],data['Year'])

# %%
### We observie the outlier for KM's
import seaborn as sb
sb.scatterplot(data['Kilometers_Driven'],data['Year'])

# %%
## Checking outlier by boxplot
sb.boxplot(data['Kilometers_Driven'])

# %%
## Maximum no of KM vehicle Ran
data['Kilometers_Driven'].max()
# Out:
# 6500000

# %%
## Minimum no of KM vehicle Ran
data['Kilometers_Driven'].min()
# Out:
# 171

# %%
### Detecting the outlier by Z-Score Method

# %%
outliers=[]
def detect_outlier(data_1):
    
    threshold=6
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
### We got the outlier 
outlier_datapoints = detect_outlier(data['Kilometers_Driven'])
print(outlier_datapoints)
# Out:
# [775000, 620000, 720000, 6500000]

# %%
## Z score method

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(data['Kilometers_Driven']))
print(z)
# Out:
# [0.14555501 0.19305462 0.13844016 ... 0.04013414 0.13844016 0.12751727]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 337,  355, 1851, 2314, 2801, 3069, 4457], dtype=int64),)

# %%
z[337]
# Out:
# 7.824347534642766

# %%
data[data['Kilometers_Driven'] == 6500000]
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 2328  BMW X5 xDrive 30d M Sport  Chennai  2017            6500000    Diesel
#
#      Transmission Owner_Type     Mileage   Engine    Power  Seats  Price
# 2328    Automatic      First  15.97 kmpl  2993 CC  258 bhp    5.0   65.0

# %%
###Droppe the outlier highest no of KM's
data.drop(2328,inplace=True)

# %%
##Verified the outlier deletion
data[data['Kilometers_Driven'] == 6500000]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, Price]
# Index: []

# %%
sb.boxplot(data['Kilometers_Driven'])

# %%
data[data['Kilometers_Driven'] == 775000]
# Out:
#                                        Name Location  Year  Kilometers_Driven  \
# 340  Skoda Octavia Ambition Plus 2.0 TDI AT  Kolkata  2013             775000
#
#     Fuel_Type Transmission Owner_Type    Mileage   Engine    Power  Seats  \
# 340    Diesel    Automatic      First  19.3 kmpl  1968 CC  141 bhp    5.0
#
#      Price
# 340    7.5

# %%
data[data['Kilometers_Driven'] == 720000]
# Out:
#                                   Name Location  Year  Kilometers_Driven  \
# 1860  Volkswagen Vento Diesel Highline  Chennai  2013             720000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 1860    Diesel       Manual      First  20.54 kmpl  1598 CC  103.6 bhp    5.0
#
#       Price
# 1860    5.9

# %%
data[data['Kilometers_Driven'] == 620000]
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 358  Hyundai i10 Magna 1.2  Chennai  2009             620000    Petrol
#
#     Transmission Owner_Type     Mileage   Engine     Power  Seats  Price
# 358       Manual      First  20.36 kmpl  1197 CC  78.9 bhp    5.0    2.7

# %%
data.drop(340,inplace=True)
data.drop(1860,inplace=True)
data.drop(358,inplace=True)

# %%
sb.boxplot(data['Kilometers_Driven'])

# %%
outliers=[]
def detect_outlier(data_1):
    
    threshold=6
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
### We got the outlier 
outlier_datapoints = detect_outlier(data['Kilometers_Driven'])
print(outlier_datapoints)
# Out:
# [299322, 282000, 480000, 480000, 300000, 445000]

# %%
##print(data[data['Kilometers_Driven'] == 480000])
##print(data[data['Kilometers_Driven'] == 445000])

# %%
data[data['Kilometers_Driven'] == 480000]
# Out:
#                                                  Name Location  Year  \
# 2823  Volkswagen Jetta 2013-2015 2.0L TDI Highline AT  Chennai  2015
# 3092                             Honda City i VTEC SV  Kolkata  2015
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 2823             480000    Diesel    Automatic      First  16.96 kmpl
# 3092             480000    Petrol       Manual      First   17.4 kmpl
#
#        Engine       Power  Seats  Price
# 2823  1968 CC  138.03 bhp    5.0   13.0
# 3092  1497 CC   117.3 bhp    5.0    5.0

# %%
data[data['Kilometers_Driven'] == 445000]
# Out:
#                                 Name   Location  Year  Kilometers_Driven  \
# 4491  Hyundai i20 Magna Optional 1.2  Bangalore  2013             445000
#
#      Fuel_Type Transmission Owner_Type    Mileage   Engine     Power  Seats  \
# 4491    Petrol       Manual      First  18.5 kmpl  1197 CC  82.9 bhp    5.0
#
#       Price
# 4491   4.45

# %%
### Deleting few more outliers which are identified
data.drop(2823,inplace=True)
data.drop(3092,inplace=True)
data.drop(4491,inplace=True)

# %% [markdown]
# ### Now the outliers have been removed from the data set

# %%
sb.boxplot(data['Kilometers_Driven'])

# %%
sb.scatterplot(data['Kilometers_Driven'],data['Year'])

# %%
data.head(2)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50

# %%
from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27
sb.scatterplot(data['Location'],data['Fuel_Type'])

# %%
sb.scatterplot(data['Kilometers_Driven'],data['Fuel_Type'])

# %%
sb.scatterplot(data['Kilometers_Driven'],data['Owner_Type'])

# %%
sb.scatterplot(data['Kilometers_Driven'],data['Mileage'])

# %%
sb.scatterplot(data['Kilometers_Driven'],data['Engine'])

# %%
sb.scatterplot(data['Kilometers_Driven'],data['Power'])

# %%
rcParams['figure.figsize'] = 15.7,8.27
sb.scatterplot(data['Kilometers_Driven'],data['Price'])

# %%
### Identifying the outlier in Price
sb.boxplot(data['Price'])

# %%
outliers=[]
def detect_outlier(data_1):
    
    threshold=8
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
### We got the outlier 
outlier_datapoints = detect_outlier(data['Price'])
print(outlier_datapoints)
# Out:
# [160.0, 120.0, 100.0]

# %%
data[data['Price'] == 160.0]
# Out:
#                                              Name   Location  Year  \
# 4079  Land Rover Range Rover 3.0 Diesel LWB Vogue  Hyderabad  2017
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 4079              25000    Diesel    Automatic      First  13.33 kmpl
#
#        Engine    Power  Seats  Price
# 4079  2993 CC  255 bhp    5.0  160.0

# %%
data[data['Price'] == 120.0]
# Out:
#                             Name Location  Year  Kilometers_Driven Fuel_Type  \
# 5781  Lamborghini Gallardo Coupe    Delhi  2011               6500    Petrol
#
#      Transmission Owner_Type   Mileage   Engine    Power  Seats  Price
# 5781    Automatic      Third  6.4 kmpl  5204 CC  560 bhp    2.0  120.0

# %%
data[data['Price'] == 100.0]
# Out:
#                         Name   Location  Year  Kilometers_Driven Fuel_Type  \
# 5919  Jaguar F Type 5.0 V8 S  Hyderabad  2015               8000    Petrol
#
#      Transmission Owner_Type    Mileage   Engine      Power  Seats  Price
# 5919    Automatic      First  12.5 kmpl  5000 CC  488.1 bhp    2.0  100.0

# %%
data.drop(4079,inplace=True)
data.drop(5781,inplace=True)

# %%
data.drop(5919,inplace=True)

# %%
data.head(2)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50

# %%
data.replace("km/kg",'',inplace=True)

# %%
data.head(2)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50

# %%
data['Engine']=data["Engine"].str.split(" ", n = 1, expand = True)

# %%
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg    998  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl   1582  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl   1199   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl   1248  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl   1968  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# import re
# str = "The rain in Spain"
# x = re.sub("\s", "9", str)
# print(x)

# %%
data['Mileage']=data["Mileage"].str.split(" ", n = 1, expand = True)

# %%
data['Power']=data["Power"].str.split(" ", n = 1, expand = True)

# %% [markdown]
# ### Cleaned the Data for the features Mileage, Engine , Power

# %%
data.head(4)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
# 2                      Honda Jazz V  Chennai  2011              46000
# 3                 Maruti Ertiga VDI  Chennai  2012              87000
#
#   Fuel_Type Transmission Owner_Type Mileage Engine  Power  Seats  Price
# 0       CNG       Manual      First    26.6    998  58.16    5.0   1.75
# 1    Diesel       Manual      First   19.67   1582  126.2    5.0  12.50
# 2    Petrol       Manual      First    18.2   1199   88.7    5.0   4.50
# 3    Diesel       Manual      First   20.77   1248  88.76    7.0   6.00

# %%
data['Location'].value_counts()
# Out:
# Mumbai        784
# Hyderabad     739
# Kochi         648
# Coimbatore    634
# Pune          613
# Delhi         548
# Kolkata       528
# Chennai       486
# Jaipur        410
# Bangalore     352
# Ahmedabad     223
# Name: Location, dtype: int64

# %% [markdown]
# ###### Feature ==== Location
# -- Mumbai 1
# -- Hyderabad 2
# -- Kochi 3
# -- Coimbatore 4
# -- Pune 5
# -- Delhi 6
# -- Kolkatta 7
# -- Kolkata 7
# -- Chennai 8
# -- Jaipur 9
# -- Bangalore 10
# -- Ahmedabad 11

# %%
##data['Location'].replace('Mumbai',1)
data['Location'].replace('Hyderabad',2,inplace=True)
data['Location'].replace('Kochi',3,inplace=True)
data['Location'].replace('Coimbatore',4,inplace=True)
data['Location'].replace('Pune',5,inplace=True)
data['Location'].replace('Delhi',6,inplace=True)
data['Location'].replace('Kolkatta',7,inplace=True)
data['Location'].replace('Kolkata',7,inplace=True)
data['Location'].replace('Chennai',8,inplace=True)
data['Location'].replace('Jaipur',9,inplace=True)
data['Location'].replace('Bangalore',10,inplace=True)
data['Location'].replace('Ahmedabad',11,inplace=True)

# %%
##data['Location'].replace('Kolkata',7,inplace=True)  
data['Location'].replace('Mumbai',1,inplace=True)

# %%
data.head()
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         1  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         5  2015              41000
# 2                      Honda Jazz V         8  2011              46000
# 3                 Maruti Ertiga VDI         8  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         4  2013              40670
#
#   Fuel_Type Transmission Owner_Type Mileage Engine  Power  Seats  Price
# 0       CNG       Manual      First    26.6    998  58.16    5.0   1.75
# 1    Diesel       Manual      First   19.67   1582  126.2    5.0  12.50
# 2    Petrol       Manual      First    18.2   1199   88.7    5.0   4.50
# 3    Diesel       Manual      First   20.77   1248  88.76    7.0   6.00
# 4    Diesel    Automatic     Second    15.2   1968  140.8    5.0  17.74

# %%
data['Fuel_Type'].value_counts()
# Out:
# Diesel    3190
# Petrol    2709
# CNG         56
# LPG         10
# Name: Fuel_Type, dtype: int64

# %%
#### Lable Encoding for Fuel Types 
#### # Classes
data['Fuel_Type'].replace('Diesel',1,inplace=True)
data['Fuel_Type'].replace('Petrol',2,inplace=True)
data['Fuel_Type'].replace('CNG',3,inplace=True)
data['Fuel_Type'].replace('LPG',3,inplace=True)

# %%
data.head(5)
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         1  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         5  2015              41000
# 2                      Honda Jazz V         8  2011              46000
# 3                 Maruti Ertiga VDI         8  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         4  2013              40670
#
#    Fuel_Type Transmission Owner_Type Mileage Engine  Power  Seats  Price
# 0          3       Manual      First    26.6    998  58.16    5.0   1.75
# 1          1       Manual      First   19.67   1582  126.2    5.0  12.50
# 2          2       Manual      First    18.2   1199   88.7    5.0   4.50
# 3          1       Manual      First   20.77   1248  88.76    7.0   6.00
# 4          1    Automatic     Second    15.2   1968  140.8    5.0  17.74

# %%
data['Transmission'].value_counts()
# Out:
# Manual       4262
# Automatic    1703
# Name: Transmission, dtype: int64

# %%
#### Lable Encoding for Fuel Types
data['Transmission'].replace('Manual',1,inplace=True)
data['Transmission'].replace('Automatic',2,inplace=True)

# %%
data.head(2)
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         1  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         5  2015              41000
#
#    Fuel_Type  Transmission Owner_Type Mileage Engine  Power  Seats  Price
# 0          3             1      First    26.6    998  58.16    5.0   1.75
# 1          1             1      First   19.67   1582  126.2    5.0  12.50

# %%
data['Owner_Type'].value_counts()
# Out:
# First             4894
# Second             953
# Third              110
# Fourth & Above       8
# Name: Owner_Type, dtype: int64

# %%
#### Lable Encoding for Fuel Types
data['Owner_Type'].replace('First',1,inplace=True)
data['Owner_Type'].replace('Second',2,inplace=True)
data['Owner_Type'].replace('Third',3,inplace=True)
data['Owner_Type'].replace('Fourth & Above',4,inplace=True)

# %%
data.head(1)
# Out:
#                      Name  Location  Year  Kilometers_Driven  Fuel_Type  \
# 0  Maruti Wagon R LXI CNG         1  2010              72000          3
#
#    Transmission  Owner_Type Mileage Engine  Power  Seats  Price
# 0             1           1    26.6    998  58.16    5.0   1.75

# %%
##data['Name'].value_counts()

# %%
data.corr()
# Out:
#                    Location      Year  Kilometers_Driven  Fuel_Type  \
# Location           1.000000 -0.124968           0.097840  -0.064796
# Year              -0.124968  1.000000          -0.501611  -0.114874
# Kilometers_Driven  0.097840 -0.501611           1.000000  -0.243591
# Fuel_Type         -0.064796 -0.114874          -0.243591   1.000000
# Transmission      -0.078051  0.095247          -0.122411  -0.145377
# Owner_Type         0.131473 -0.394226           0.252473   0.041812
# Seats              0.001681  0.012305           0.240631  -0.301801
# Price             -0.063876  0.312709          -0.183645  -0.327858
#
#                    Transmission  Owner_Type     Seats     Price
# Location              -0.078051    0.131473  0.001681 -0.063876
# Year                   0.095247   -0.394226  0.012305  0.312709
# Kilometers_Driven     -0.122411    0.252473  0.240631 -0.183645
# Fuel_Type             -0.145377    0.041812 -0.301801 -0.327858
# Transmission           1.000000   -0.009618 -0.073270  0.595708
# Owner_Type            -0.009618    1.000000  0.016260 -0.105212
# Seats                 -0.073270    0.016260  1.000000  0.067716
# Price                  0.595708   -0.105212  0.067716  1.000000

# %%
sb.scatterplot(data['Year'],data['Price'])

# %%
sb.scatterplot(data['Price'],data['Kilometers_Driven'])

# %%
sb.distplot(data['Price'])
# Out:
# C:\Users\sgudda\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sb.scatterplot(data['Fuel_Type'],data['Transmission'])

# %%
data.head(2)
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         1  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         5  2015              41000
#
#    Fuel_Type  Transmission  Owner_Type  Mileage  Engine  Power  Seats  Price
# 0          3             1           1    26.60   998.0    NaN    5.0   1.75
# 1          1             1           1    19.67  1582.0    NaN    5.0  12.50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5965 entries, 0 to 6018
# Data columns (total 12 columns):
# Name                 5965 non-null object
# Location             5965 non-null int64
# Year                 5965 non-null int64
# Kilometers_Driven    5965 non-null int64
# Fuel_Type            5965 non-null int64
# Transmission         5965 non-null int64
# Owner_Type           5965 non-null int64
# Mileage              5965 non-null float64
# Engine               5965 non-null object
# Power                5965 non-null object
# Seats                5965 non-null float64
# Price                5965 non-null float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 605.8+ KB

# %%
data.Mileage = data.Mileage.astype('float64')

# %%
##data.Engine = data.Engine.astype('float64') 
##data.Power = data.Power.astype('float64') 
##df['Car_Brand'] = df['Car_Brand'].strip()
data['Power'] =data['Power'].str.strip([])

# %%
## Dropping the column
data.drop(['Power'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5965 entries, 0 to 6018
# Data columns (total 11 columns):
# Name                 5965 non-null object
# Location             5965 non-null int64
# Year                 5965 non-null int64
# Kilometers_Driven    5965 non-null int64
# Fuel_Type            5965 non-null int64
# Transmission         5965 non-null int64
# Owner_Type           5965 non-null int64
# Mileage              5965 non-null float64
# Engine               5965 non-null float64
# Seats                5965 non-null float64
# Price                5965 non-null float64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 719.2+ KB

# %%
## Checking the Co-Relation for the each features
corr = data.corr()
corr.style.background_gradient(cmap='PuBu',low=0, high=0, axis=0, subset=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col0 {
#             background-color:  #023858;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col1 {
#             background-color:  #d0d1e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col2 {
#             background-color:  #9cb9d9;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col3 {
#             background-color:  #ced0e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col4 {
#             background-color:  #dcdaeb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col5 {
#             background-color:  #a5bddb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col6 {
#             background-color:  #9fbad9;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col7 {
#             background-color:  #abbfdc;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col8 {
#             background-color:  #d2d3e7;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow0_col9 {
#             background-color:  #dcdaeb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col0 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col1 {
#             background-color:  #023858;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col2 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col3 {
#             background-color:  #d7d6e9;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col4 {
#             background-color:  #b7c5df;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col5 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col6 {
#             background-color:  #509ac6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col7 {
#             background-color:  #b1c2de;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col8 {
#             background-color:  #d1d2e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow1_col9 {
#             background-color:  #7bacd1;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col0 {
#             background-color:  #dcdaeb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col1 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col2 {
#             background-color:  #023858;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col3 {
#             background-color:  #ebe6f2;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col4 {
#             background-color:  #e4e1ef;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col5 {
#             background-color:  #83afd3;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col6 {
#             background-color:  #c9cee4;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col7 {
#             background-color:  #79abd0;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col8 {
#             background-color:  #94b6d7;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow2_col9 {
#             background-color:  #efe9f3;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col0 {
#             background-color:  #f7f0f7;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col1 {
#             background-color:  #ced0e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col2 {
#             background-color:  #e2dfee;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col3 {
#             background-color:  #023858;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col4 {
#             background-color:  #e7e3f0;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col5 {
#             background-color:  #bbc7e0;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col6 {
#             background-color:  #b7c5df;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col7 {
#             background-color:  #f0eaf4;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col8 {
#             background-color:  #fef6fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow3_col9 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col0 {
#             background-color:  #f9f2f8;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col1 {
#             background-color:  #9ebad9;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col2 {
#             background-color:  #d0d1e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col3 {
#             background-color:  #dbdaeb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col4 {
#             background-color:  #023858;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col5 {
#             background-color:  #c8cde4;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col6 {
#             background-color:  #e4e1ef;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col7 {
#             background-color:  #1e80b8;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col8 {
#             background-color:  #e0dded;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow4_col9 {
#             background-color:  #197db7;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col0 {
#             background-color:  #d5d5e8;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col1 {
#             background-color:  #f4eef6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col2 {
#             background-color:  #73a9cf;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col3 {
#             background-color:  #b5c4df;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col4 {
#             background-color:  #d1d2e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col5 {
#             background-color:  #023858;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col6 {
#             background-color:  #c8cde4;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col7 {
#             background-color:  #9ab8d8;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col8 {
#             background-color:  #d0d1e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow5_col9 {
#             background-color:  #e3e0ee;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col0 {
#             background-color:  #eae6f1;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col1 {
#             background-color:  #5ea0ca;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col2 {
#             background-color:  #d6d6e9;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col3 {
#             background-color:  #d1d2e6;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col4 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col5 {
#             background-color:  #e3e0ee;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col6 {
#             background-color:  #023858;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col7 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col8 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow6_col9 {
#             background-color:  #fef6fa;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow7_col0 {
#             background-color:  #f1ebf5;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow7_col1 {
#             background-color:  #c0c9e2;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow7_col2 {
#             background-color:  #88b1d4;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow7_col3 {
#             background-color:  #fff7fb;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow7_col4 {
#             background-color:  #358fc0;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow7_col5 {
#             background-color:  #b9c6e0;
#         }    #T_01b1034c_9d94_11e9_8ccd_e86a648a4dcerow7_col6 {
#             bac

# %%
data.head(5)
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         1  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         5  2015              41000
# 2                      Honda Jazz V         8  2011              46000
# 3                 Maruti Ertiga VDI         8  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         4  2013              40670
#
#    Fuel_Type  Transmission  Owner_Type  Mileage  Engine  Seats  Price
# 0          3             1           1    26.60   998.0    5.0   1.75
# 1          1             1           1    19.67  1582.0    5.0  12.50
# 2          2             1           1    18.20  1199.0    5.0   4.50
# 3          1             1           1    20.77  1248.0    7.0   6.00
# 4          1             2           2    15.20  1968.0    5.0  17.74

# %%
sb.scatterplot(data['Engine'],data['Power'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score


X = data[['Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage','Engine','Seats']]
y = data.Price
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)

clf_rf = RandomForestRegressor(random_state=43)      
clr_rf = clf_rf.fit(X_train,y_train)

model = RandomForestRegressor(n_estimators=25, random_state=11)
model.fit(X_train, y_train)

clf_rf_5 = RandomForestRegressor()      
clr_rf_5 = clf_rf_5.fit(X_train,y_train)
importances = clr_rf_5.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf_rf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest

plt.figure(1, figsize=(14, 13))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
       color="g", yerr=std[indices], align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices],rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()
# Out:
# C:\Users\sgudda\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\sgudda\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Feature ranking:
# 1. feature 7 (0.539700)
# 2. feature 1 (0.166697)
# 3. feature 4 (0.115979)
# 4. feature 2 (0.081273)
# 5. feature 6 (0.044788)
# 6. feature 8 (0.025700)
# 7. feature 0 (0.020023)
# 8. feature 3 (0.003049)
# 9. feature 5 (0.002790)

# %%
# Import the necessary libraries first
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X = data[['Location','Year','Kilometers_Driven','Transmission','Owner_Type','Mileage','Engine','Seats']]
y = data.Price

# %%
## Importing the Random forest Classifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
X = data[['Location','Year','Kilometers_Driven','Transmission','Mileage','Engine','Seats']]
y = data.Price

# %%
R_model=RandomForestRegressor(n_estimators=100)
R_model.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# print the intercept
print(lm.intercept_)
# Out:
# -1861.9871938243718

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# print the intercept
print(lm.intercept_)
# Out:
# -1861.9871938243718

# %%
# print the coefficients
print(lm.intercept_)
print(lm.coef_)
# Out:
# -1861.9871938243718
# [ 2.55975158e-02  9.27913077e-01 -3.43713715e-05 -2.37645328e+00
#   5.66159129e+00  1.52180733e-01 -1.70245198e-01  1.00509460e-02
#  -2.28901957e+00]

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sb.distplot((y_test-predictions),bins=50);
# Out:
# C:\Users\sgudda\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 4.0798792242844675
# MSE: 47.32595114410361
# RMSE: 6.879385956908044

# %%
## Importing the Random forest Classifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
X = data[['Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage','Engine','Seats']]
y = data.Price

# %% [markdown]
# ## Training the Model
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)
# model = RandomForestClassifier()
# model.fit(X,y)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5965 entries, 0 to 6018
# Data columns (total 11 columns):
# Name                 5965 non-null object
# Location             5965 non-null int64
# Year                 5965 non-null int64
# Kilometers_Driven    5965 non-null int64
# Fuel_Type            5965 non-null int64
# Transmission         5965 non-null int64
# Owner_Type           5965 non-null int64
# Mileage              5965 non-null float64
# Engine               5965 non-null float64
# Seats                5965 non-null float64
# Price                5965 non-null float64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 719.2+ KB

# %%
X = data[['Location', 'Year', 'Kilometers_Driven','Fuel_Type', 'Transmission','Owner_Type','Mileage','Engine','Seats']]
y = data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# print the intercept
print(lm.intercept_)
# Out:
# -1861.9871938243718

# %%
# print the coefficients
print(lm.intercept_)
print(lm.coef_)
# Out:
# -1861.9871938243718
# [ 2.55975158e-02  9.27913077e-01 -3.43713715e-05 -2.37645328e+00
#   5.66159129e+00  1.52180733e-01 -1.70245198e-01  1.00509460e-02
#  -2.28901957e+00]

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                    Coefficient
# Location              0.025598
# Year                  0.927913
# Kilometers_Driven    -0.000034
# Fuel_Type            -2.376453
# Transmission          5.661591
# Owner_Type            0.152181
# Mileage              -0.170245
# Engine                0.010051
# Seats                -2.289020

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sb.distplot((y_test-predictions),bins=50);
# Out:
# C:\Users\sgudda\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 4.029671832532681
# MSE: 39.6879551114991
# RMSE: 6.299837705171388

# %% [markdown]
# from sklearn.metrics import accuracy_score
# print(accuracy_score(y_test,predictions))

# %%
X = data[['Location', 'Year', 'Fuel_Type', 'Transmission','Owner_Type']]
y = data['Price']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)
from sklearn.linear_model import LinearRegression

# %%
lm1=LinearRegression()
lm1.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# print the intercept
print(lm.intercept_)
# Out:
# -1861.9871938243718

# %%
# print the coefficients
print(lm1.intercept_)
print(lm1.coef_)
# Out:
# -1540.9258462734701
# [-0.03602578  0.76507294 -4.81161287 13.11299622  0.33400543]

# %%
coeff_df = pd.DataFrame(lm1.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#               Coefficient
# Location        -0.036026
# Year             0.765073
# Fuel_Type       -4.811613
# Transmission    13.112996
# Owner_Type       0.334005

# %%
predictions = lm1.predict(X_test)
plt.scatter(y_test,predictions)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 4.805601932771097
# MSE: 64.54842107353429
# RMSE: 8.034203200911357

# %%
testing = pd.read_excel('Data_Test.xlsx')

# %%
testing.head(4)
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# 2  147.8 bhp    7.0  25.27 Lakh
# 3   null bhp    5.0         NaN

# %%
data.shape
# Out:
# (5965, 12)

# %%
testing.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 10
# Power                  10
# Seats                  11
# New_Price            1052
# dtype: int64

# %%
sb.distplot((y_test-predictions),bins=50);
# Out:
# C:\Users\sgudda\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.decomposition import PCA
X = data[['Location', 'Year', 'Kilometers_Driven','Fuel_Type', 'Transmission','Owner_Type','Mileage','Engine','Seats']]
y = data['Price']
pca = PCA()
X_pca = pd.DataFrame(pca.fit_transform(X))
from sklearn.model_selection import train_test_split
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca,y,test_size=0.3,random_state=10)

# %%
X_train_pca.columns= ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9']
X_train_pca.head()
# Out:
#                 PC1          PC2       PC3       PC4       PC5       PC6  \
# 1963   53911.703945  -729.544526  2.044095  3.371512  0.030131  0.256927
# 1873  -51081.679650  1528.556222  0.506867  1.026044 -2.750064 -1.049802
# 3241  -16277.354070  -320.590523 -8.130621 -1.287005  2.495227 -0.198148
# 5117  -18084.514162   580.165161 -2.840777  3.760958 -2.410475  0.653653
# 1432  174585.479190  -675.202842 -1.632191 -1.645242 -3.509715  1.333955
#
#            PC7       PC8       PC9
# 1963  0.542272  0.262167 -0.115084
# 1873  0.046934 -0.095602 -0.219146
# 3241 -0.013940 -0.124308  0.120488
# 5117 -0.082981 -0.277804 -0.269980
# 1432 -0.459511  0.912544 -0.229714

# %%
pca.explained_variance_ratio_[0:1].sum()
# Out:
# 0.9996968086281682

# %%
##from sklearn.metrics import accuracy_score
##from sklearn.ensemble import RandomForestClassifier
##model = RandomForestClassifier(max_depth=6, n_estimators=20,                              random_state=128)
lm1.fit(X_train_pca.[0:2], y_train)
y_predict = model.predict(X_test_pca.[0:2])
accuracy_score(y_test, y_predict)
# Out:
#   File "<ipython-input-218-2f13086d468c>", line 4
#     lm1.fit(X_train_pca.[0:2], y_train)
#                         ^
# SyntaxError: invalid syntax

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
